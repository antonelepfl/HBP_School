# %% [markdown]
# # Download circuit and install dependencies

# %%
# !pip install -q --upgrade pip

# %%
# !curl -s -O https://raw.githubusercontent.com/antonelepfl/HBP_School/master/requirements_new.txt

# %%
# !pip install --no-cache-dir -q -r requirements_new.txt

# %%
# !pip install -q -i https://bbpteam.epfl.ch/repository/devpi/simple --no-cache-dir --upgrade --force-reinstall numpy pandas brain

# %%
# !curl -s 'https://bbp.epfl.ch/public/bsp-palermo-2018/circuit.tar.gz' | tar xz -C $HOME

# %%
# !ln -s circuit/morphologies/h5v1 circuit/morphologies/v1
