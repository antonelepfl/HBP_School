# %% [markdown]
# # Simulation
#
# Perform basic analyses on a simulation

# %%
import matplotlib.pyplot as plt
import numpy as np

from bluepy.v2 import Simulation

# %%
sim = Simulation('/gpfs/bbp.cscs.ch/project/proj42/circuits/O1/20180907/simulation/20180907/BlueConfig')

# %%
gids = sim.circuit.cells.ids('SP_PC', sample=100)

# %%
sim.plot.raster(gids, t_start=0);

# %%
sim.plot.firing_rate_histogram(gids, t_start=0);

# %%
sim.plot.isi(gids, t_start=0);
# Out:
# /home/povolots/opt/pyenv/versions/3.6.4/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sim.plot.voltage_collage('soma', group=gids[:5], t_start=0);
